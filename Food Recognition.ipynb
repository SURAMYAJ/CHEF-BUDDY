# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(rescale=1./255,
                                 shear_range=0.2,
                                 zoom_range=0.2,
                                 horizontal_flip=True)
training_set=train_datagen.flow_from_directory('4)Food Recognition/Train',
                                              target_size=(64,64),
                                              batch_size=32,
                                              class_mode='categorical')
# Out:
# Found 2745 images belonging to 61 classes.

# %%
test_datagen=ImageDataGenerator(rescale=1./255)
test_set=test_datagen.flow_from_directory('4)Food Recognition/Test',
                                         target_size=(64,64),
                                         batch_size=32,
                                         class_mode='categorical')
# Out:
# Found 305 images belonging to 61 classes.

# %%
cnn=tf.keras.models.Sequential()

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu',input_shape=[64,64,3]))

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=128,activation='relu'))

# %%
cnn.add(tf.keras.layers.Dense(units=61,activation='softmax'))

# %%
cnn.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
cnn.fit(x=training_set,validation_data=test_set,epochs=100)
# Out:
# Epoch 1/100
# 86/86 [==============================] - 19s 215ms/step - loss: 4.0748 - accuracy: 0.0240 - val_loss: 3.9376 - val_accuracy: 0.0459
# Epoch 2/100
# 86/86 [==============================] - 17s 203ms/step - loss: 3.8005 - accuracy: 0.0590 - val_loss: 3.6004 - val_accuracy: 0.0721
# Epoch 3/100
# 86/86 [==============================] - 16s 188ms/step - loss: 3.6102 - accuracy: 0.0765 - val_loss: 3.3622 - val_accuracy: 0.1148
# Epoch 4/100
# 86/86 [==============================] - 16s 191ms/step - loss: 3.4631 - accuracy: 0.1093 - val_loss: 3.2699 - val_accuracy: 0.1410
# Epoch 5/100
# 86/86 [==============================] - 16s 186ms/step - loss: 3.3577 - accuracy: 0.1290 - val_loss: 3.0753 - val_accuracy: 0.1607
# Epoch 6/100
# 86/86 [==============================] - 17s 194ms/step - loss: 3.2448 - accuracy: 0.1523 - val_loss: 2.9254 - val_accuracy: 0.2262
# Epoch 7/100
# ...

# %%
training_set.class_indices
# Out:
# {'adhirasam': 0,
#  'aloo_gobi': 1,
#  'aloo_matar': 2,
#  'aloo_tikki': 3,
#  'anarsa': 4,
#  'bandar_laddu': 5,
#  'basundi': 6,
#  'bhatura': 7,
#  'bhindi_masala': 8,
#  'biryani': 9,
#  'boondi': 10,
#  'butter_chicken': 11,
#  'chak_hao_kheer': 12,
#  'chana_masala': 13,
#  'chapati': 14,
#  'chicken_razala': 15,
#  'chicken_tikka': 16,
#  'chicken_tikka_masala': 17,
#  'chikki': 18,
#  'daal_baati_churma': 19,
#  'dal_makhani': 20,
#  'dal_tadka': 21,
#  'dharwad_pedha': 22,
#  'doodhpak': 23,
#  'dum_aloo': 24,
#  'gajar_ka_halwa': 25,
#  'ghevar': 26,
#  'gulab_jamun': 27,
#  'imarti': 28,
#  'jalebi': 29,
#  'kachori': 30,
#  'kadhi_pakoda': 31,
#  'kalakand': 32,
#  'karela_bharta': 33,
#  'kofta': 34,
#  'lassi': 35,
#  'litti_chokha': 36,
#  'makki_di_roti_sarson_da_saag': 37,
#  'malapua': 38,
#  'misi_roti': 39,
#  'modak': 40,
#  'mysore_pak': 41,
#  'naan': 42,
#  'navrattan_korma': 43,
#  'palak_paneer': 44,
#  'paneer_butter_masala': 45,
#  'phirni': 46,
# ...

# %%
import numpy as np
from keras.preprocessing import image
from keras.utils import load_img, img_to_array

# %%
test_image = load_img("4)Food Recognition/Train/daal_baati_churma/2d10f06c50.jpg", target_size = (64,64))
test_image = img_to_array(test_image)
  #Need to convert in the same form as input
test_image=np.expand_dims(test_image,axis=0) #To show batches
result=cnn.predict(test_image)
prediction=np.argmax(result, axis=1)
if prediction==0:
    print("ADHIRASAM")
elif prediction==1:
    print("ALOO GOBI")
elif prediction==2:
    print("ALOO TIKKI")
elif prediction==3:
    print("ALOO METHI")
elif prediction==4:
    print("ANARASA")
elif prediction==5:
    print("BANDAR LADU")    
elif prediction==6:
    print("BASUNDI")   
elif prediction==7:
    print("BHATURA")    
elif prediction==8:
    print("BHINDI MASLA")
elif prediction==9:
    print("BIRYANI")
elif prediction==10:
    print("BOONDI")
elif prediction==11:
    print("BUTTER CHICKEN")
elif prediction==12:
    print("CHAK HAO KHEER")
elif prediction==13:
    print("CHANA MASLA")
elif prediction==14:
    print("CHAPATI")
elif prediction==15:
    print("CHIKEN RAZALA")
elif prediction==16:
    print("CHICKEN TIKKA")
elif prediction==17:
    print("CHICKEN TIKKA MASALA")
elif prediction==18:
    print("CHIKKI")
elif prediction==19:
    print("DAL BATI CHURMA")
elif prediction==20:
    print("DAL MAKHANI")
elif prediction==21:
    print("DAL TADKA")
elif prediction==22:
    print("PEDHA")
elif prediction==23:
    print("DOODHPAK")
elif prediction==24:
    print("DUM ALOO")
elif prediction==25:
    print("GAJAR KA HALWA")
elif prediction==26:
    print("GHEVAR")
elif prediction==27:
    print("GULAB JAMUN")
elif prediction==28:
    print("IMARTI")
elif prediction==29:
    print("JALEBI")
elif prediction==30:
    print("KACHORI")    
elif prediction==31:
    print("KADHI PAKORA")
elif prediction==32:
    print("KALAKAND")
elif prediction==33:
    print("KARELA BHARTA")
elif prediction==34:
    print("KOFTA")
elif prediction==35:
    print("LASSI")
elif prediction==36:
    print("LITI CHOKHA")        
elif prediction==37:
    print("MAKKI DI ROTI SARSO KA SAAG")
elif prediction==38:
    print("MALAPUA")
elif prediction==39:
    print("MISI ROTI")
elif prediction==40:
    print("MODAK")
elif prediction==41:
    print("MYSORE PAAK") 
elif prediction==42:
    print("NAAN")
elif prediction==43:
    print("NAVRATAN KORMA")
elif prediction==44:
    print("PALAK PANEER")
elif prediction==45:
    print("PANEER BUTTER MASALA")
elif prediction==46:
    print("PHIRNI")     
elif prediction==47:
    print("PITHE")
elif prediction==48:
    print("POHA")
elif prediction==49:
    print("POORNALU")
elif prediction==50:
    print("POOTHAREKULU")
elif prediction==51:
    print("REBRI")
elif prediction==52:
    print("RASMALAI")
elif prediction==53:
    print("RASGULA ")
elif prediction==54:
    print("SHANKARPALI")
elif prediction==55:
    print("SHEERKORMA")
elif prediction==56:
    print("SHEERA") 
elif prediction==57:
    print("SHRIKHAD")
elif prediction==58:
    print("SOHAN HALWA")
elif prediction==59:
    print("SOAN PAPDI")
elif prediction==60:
    print("SUTAR FENI")      
else:
    print('SOMETHING VERY NEW AND TASTY')
# Out:
# 1/1 [==============================] - 0s 21ms/step
# DAL BATI CHURMA
